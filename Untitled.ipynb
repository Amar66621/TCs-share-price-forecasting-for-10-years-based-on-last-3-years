# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('TCS.NS.csv')

# %%
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2021-10-18  3603.449951  3652.699951  3601.449951  3647.149902
# 1    2021-10-19  3669.000000  3690.100098  3625.199951  3634.149902
# 2    2021-10-20  3612.000000  3630.000000  3578.300049  3608.850098
# 3    2021-10-21  3604.100098  3607.449951  3511.250000  3532.500000
# 4    2021-10-22  3560.000000  3561.600098  3485.000000  3498.850098
# ..          ...          ...          ...          ...          ...
# 490  2023-10-09  3645.050049  3679.000000  3631.000000  3638.350098
# 491  2023-10-10  3640.050049  3648.000000  3601.350098  3628.899902
# 492  2023-10-11  3650.000000  3650.000000  3605.000000  3609.899902
# 493  2023-10-12  3575.000000  3588.649902  3538.100098  3542.550049
# 494  2023-10-13  3530.000000  3577.000000  3525.000000  3570.850098
#
#        Adj Close   Volume
# 0    3491.024658  3590107
# 1    3478.580811  3135441
# 2    3454.364014  2933693
# 3    3381.282715  4871211
# ...

# %%
df.drop('Adj Close', axis = 1,inplace=True)

# %%
df.head()
# Out:
#          Date         Open         High          Low        Close   Volume
# 0  2021-10-18  3603.449951  3652.699951  3601.449951  3647.149902  3590107
# 1  2021-10-19  3669.000000  3690.100098  3625.199951  3634.149902  3135441
# 2  2021-10-20  3612.000000  3630.000000  3578.300049  3608.850098  2933693
# 3  2021-10-21  3604.100098  3607.449951  3511.250000  3532.500000  4871211
# 4  2021-10-22  3560.000000  3561.600098  3485.000000  3498.850098  2691670

# %%
df.isnull().sum()
# Out:
# Date      0
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Close'], label='Historical', marker='o')
plt.xlabel('Year')
plt.ylabel('Closing Price')
# Out:
# Text(0, 0.5, 'Closing Price')

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Close'], label='Historical', marker='o')
plt.xlabel('Year')
plt.ylabel('Closing Price')
# Out:
# Text(0, 0.5, 'Closing Price')

# %%
plt.figure(figsize=(12, 6))
plt.bar(df['Date'], df['Close'], width=20, align='center', alpha=0.7)
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('Historical Closing Prices for TCS')
plt.xticks(rotation=120)
plt.grid(axis='y')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Close'], marker='o', linestyle='-', markersize=3)
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.title('Historical Closing Prices for TCS')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
x = df[['Open','High','Low','Volume']]
y = df[['Close']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20, random_state=0)

# %%
x_test.shape
# Out:
# (99, 4)

# %%
x_train.shape
# Out:
# (396, 4)

# %%
y_test.shape
# Out:
# (99, 1)

# %%
y_train.shape
# Out:
# (396, 1)

# %%
LR = LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(LR.coef_)
# Out:
# [[-6.33364288e-01  9.21534904e-01  7.11281904e-01 -3.15592328e-06]]

# %%
LR.intercept_
# Out:
# array([4.92315486])

# %%
predict = LR.predict(x_test)

# %%
print(x_test)
# Out:
#             Open         High          Low   Volume
# 90   3474.000000  3483.850098  3391.100098  5039136
# 254  3180.500000  3184.250000  3151.149902  2069643
# 283  3368.300049  3393.699951  3354.000000  1167505
# 442  3385.000000  3393.699951  3331.000000  2599831
# 336  3494.000000  3508.899902  3444.750000  1139541
# ..           ...          ...          ...      ...
# 179  3218.500000  3268.500000  3202.250000  2182144
# 372  3130.750000  3140.000000  3071.500000  3298034
# 56   3812.000000  3835.000000  3772.000000  1810293
# 437  3404.050049  3434.899902  3359.050049  3770223
# 60   3925.000000  3929.000000  3836.550049  3203744
#
# [99 rows x 4 columns]

# %%
y_test=y_test.values.ravel()

# %%
predict.shape
# Out:
# (99, 1)

# %%
predict = predict.flatten()

# %%
predict.shape
# Out:
# (99,)

# %%
df1 = pd.DataFrame(y_test,predict)

# %%
df2 = pd.DataFrame({'Actual price':y_test,'Predicted price':predict})

# %%
df2
# Out:
#     Actual price  Predicted price
# 0    3401.649902      3411.230093
# 1    3162.100098      3159.729824
# 2    3380.600098      3380.930102
# 3    3355.399902      3349.473155
# 4    3451.000000      3472.114103
# ..           ...              ...
# 94   3260.750000      3249.292827
# 95   3089.600098      3089.931536
# 96   3807.449951      3801.867043
# 97   3368.300049      3391.632552
# 98   3859.899902      3858.436817
#
# [99 rows x 2 columns]

# %%
df2.head(25)
# Out:
#     Actual price  Predicted price
# 0    3401.649902      3411.230093
# 1    3162.100098      3159.729824
# 2    3380.600098      3380.930102
# 3    3355.399902      3349.473155
# 4    3451.000000      3472.114103
# 5    3505.699951      3521.722617
# 6    3414.899902      3393.220151
# 7    3536.750000      3548.316989
# 8    3404.149902      3383.537929
# 9    3364.350098      3348.180112
# 10   3101.949951      3107.353907
# 11   3121.850098      3124.994333
# 12   3282.149902      3281.012145
# 13   3305.100098      3320.329303
# 14   3293.100098      3297.151692
# 15   3520.100098      3531.795191
# 16   3376.149902      3377.558262
# 17   3179.300049      3193.140907
# 18   3355.199951      3352.247933
# 19   3636.800049      3628.678599
# 20   3401.550049      3390.553794
# 21   3239.800049      3252.963095
# 22   3091.149902      3084.209174
# 23   3749.850098      3747.044232
# 24   3630.750000      3622.245642

# %%
LR.score(x_test,y_test)
# Out:
# 0.9952369842655606

# %%
from sklearn import metrics

# %%
print('Mean absolute Error:', metrics.mean_absolute_error(y_test,predict))
print('Mean Squared Error:', metrics.mean_squared_error(y_test,predict))
print('RMean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test,predict)))
# Out:
# Mean absolute Error: 11.391319519848517
# Mean Squared Error: 195.30034465178156
# RMean Squared Error: 13.974989969648693

# %%
import warnings

# Before making predictions
warnings.filterwarnings("ignore", category=UserWarning)

# %%
X = x_test.iloc[-1][['Open', 'High', 'Low', 'Volume']].values.reshape(1, -1)  # Select 'Open', 'High', 'Low', and 'Volume'

# %%
X.shape
# Out:
# (1, 4)

# %%
X = x_test.iloc[-1][['Open', 'High', 'Low', 'Volume']].values.reshape(1, -1)  # Select 'Open', 'High', 'Low', and 'Volume'
n = 10
prices =[]
for i in range(n):
    next_prediction = LR.predict(X)
    prices.append(next_prediction[0])
    X =  x_test.iloc[-1 -i][['Open', 'High', 'Low', 'Volume']].values.reshape(1, -1)

# %%
print(prices)
# Out:
# [array([3858.43681705]), array([3858.43681705]), array([3391.63255186]), array([3801.86704327]), array([3089.93153574]), array([3249.29282684]), array([3350.89205265]), array([3200.52276876]), array([3335.67394708]), array([3116.79173958])]
